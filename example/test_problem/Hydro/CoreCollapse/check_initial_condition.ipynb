# %%
import yt
import numpy as np

# %% [markdown]
# In the code units, we have
# UNIT_L = 1e5
# UNIT_M = 1.989e33
# UNIT_T = 1e-3
#
# So, UNIT_D =

# %%
unit_L = 1.e5
unit_M = 1.989e33
unit_T = 1.e-3
unit_D = 1./(unit_M/(unit_L**3))
print(unit_D)
# Out:
# 5.027652086475616e-19

# %%
colormap    = 'arbre'
field       = 'density'

# %%
ds = yt.load('Data_000014')
# Out:
# yt : [INFO     ] 2018-10-14 17:40:17,923 Parameters: current_time              = 908.6728820915159
# yt : [INFO     ] 2018-10-14 17:40:17,924 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2018-10-14 17:40:17,939 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-10-14 17:40:17,944 Parameters: domain_right_edge         = [10000. 10000. 10000.]
# yt : [INFO     ] 2018-10-14 17:40:17,944 Parameters: cosmological_simulation   = 0

# %%
slice = yt.SlicePlot( ds, 'z', field,)
slice.set_log( field, True )
slice.set_unit( field, 'code_mass/code_length**3' )
slice.set_cmap( field, colormap )
slice.annotate_grids( periodic=False )
#slice.zoom(10)
#slice.save()
# Out:
# /Users/pan/anaconda3/envs/python3/lib/python3.6/site-packages/yt/units/yt_array.py:978: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   ret = super(YTArray, self).__getitem__(item)
# /Users/pan/anaconda3/envs/python3/lib/python3.6/site-packages/yt/fields/fluid_fields.py:201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   new_field[slice_3d] = f
# yt : [INFO     ] 2018-10-14 17:40:19,835 xlim = 0.000000 10000.000000
# yt : [INFO     ] 2018-10-14 17:40:19,836 ylim = 0.000000 10000.000000
# ...

# %%
field= 'radial_velocity'
#field = 'velocity_x'
slice = yt.SlicePlot( ds, 'z', field,)
slice.set_log( field, False )
slice.set_cmap( field, colormap )
slice.annotate_grids( periodic=False )
# Out:
# yt : [INFO     ] 2018-10-14 17:40:29,212 xlim = 0.000000 10000.000000
# yt : [INFO     ] 2018-10-14 17:40:29,212 ylim = 0.000000 10000.000000
# yt : [INFO     ] 2018-10-14 17:40:29,213 xlim = 0.000000 10000.000000
# yt : [INFO     ] 2018-10-14 17:40:29,213 ylim = 0.000000 10000.000000
# yt : [INFO     ] 2018-10-14 17:40:29,214 Making a fixed resolution buffer of (('gas', 'radial_velocity')) 800 by 800
# yt : [WARNING  ] 2018-10-14 17:40:29,333 Plot image for field ('gas', 'radial_velocity') has both positive and negative values. Min = -628159930.621665, Max = 7550577.391065.
# yt : [WARNING  ] 2018-10-14 17:40:29,335 Switching to symlog colorbar scaling unless linear scaling is specified later
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
v, c = ds.find_max("density")
print(v)

# %%
ds.field_list

# %%
ds.derived_field_list
